# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\tanma\appdata\local\programs\python\python39\lib\site-packages (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tanma\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tanma\appdata\roaming\python\python39\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\tanma\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tanma\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\tanma\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Users\tanma\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
import pandas as pd

# %%
df= pd.read_csv("E:\\Synthetic-Email-Generation-tool-main\\data\\combined_with_candidate_application.csv")

# %%
df.info()
df.head()
df['label'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3671 entries, 0 to 3670
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   3671 non-null   object
#  1   text    3671 non-null   object
# dtypes: object(2)
# memory usage: 57.5+ KB
# label
# job_application          1023
# candidate_application     596
# spam                      524
# new_requisition           516
# interview_scheduling      510
# candidate_selection       502
# Name: count, dtype: int64
