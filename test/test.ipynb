# %%
# %pip install pandas
# Out:
# ...
#      ---------------------------------------- 11.4/11.4 MB 6.9 MB/s eta 0:00:00
# ...
#      ------------------------------------- 348.5/348.5 KB 10.6 MB/s eta 0:00:00
# ...
#      --------------------------------------- 15.9/15.9 MB 12.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 509.2/509.2 KB 4.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\tanma\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Users\tanma\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df= pd.read_csv("E:\\Synthetic-Email-Generation-tool-main\\Candidate_application\\candidate_application_labeled.csv")

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   402 non-null    object
#  1   text    402 non-null    object
# dtypes: object(2)
# memory usage: 6.4+ KB
#                    label                                               text
# 0  candidate_application  Subject: Application Received – Ethan Patel\n\...
# 1  candidate_application  Subject: Application Received – Ethan Patel\n\...
# 2  candidate_application  Subject: Application Received – Ethan Patel\n\...
# 3  candidate_application  Subject: Application Received – Emily Patel\n\...
# 4  candidate_application  Subject: Application Received – Emily Patel\n\...
